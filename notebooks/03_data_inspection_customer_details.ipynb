# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers_2012 = pd.read_excel("../data/raw/customer-details.xlsx", sheet_name=0)
customers_2012.head()
# Out:
#    Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0           0  161770        1         0  2012-04-04                 29
# 1           1   85477        1         1  2012-12-30                  7
# 2           2  147233        1         1  2012-02-02                  5
# 3           3  121393        1         2  2012-12-21                 29
# 4           4   63164        1         2  2012-06-20                 20
#
#                                      ID
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079
# 1  e9d37224-cb6f-4942-98d7-46672963d097
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b
# 3  9991fafb-4447-451a-8be2-b0df6098d13e
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb

# %%
customers_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20115 entries, 0 to 20114
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         20115 non-null  int64
#  1   Income             20115 non-null  int64
#  2   Kidhome            20115 non-null  int64
#  3   Teenhome           20115 non-null  int64
#  4   Dt_Customer        20115 non-null  datetime64[ns]
#  5   NumWebVisitsMonth  20115 non-null  int64
#  6   ID                 20115 non-null  object
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 1.1+ MB

# %%
customers_2013 = pd.read_excel("../data/raw/customer-details.xlsx", sheet_name=1)
customers_2013.head()
# Out:
#    Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0           0   82407        0         1  2013-10-07                 29
# 1           1   24877        0         0  2013-04-21                 32
# 2           2   78839        1         0  2013-11-25                 21
# 3           3  113859        1         1  2013-01-06                 12
# 4           4  147317        0         0  2013-07-10                 14
#
#                                      ID
# 0  ef81336c-e41a-46d0-8a30-5d4ac3b836be
# 1  50b224ac-84b4-42a7-aba9-3e1d1d620479
# 2  9cb15c53-b647-464a-add9-09cdae04897c
# 3  f8aaf334-949d-4943-a214-b64fe9c088b4
# 4  885fe85a-3718-4760-a32a-a57628cf7528

# %%
customers_2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8965 entries, 0 to 8964
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         8965 non-null   int64
#  1   Income             8965 non-null   int64
#  2   Kidhome            8965 non-null   int64
#  3   Teenhome           8965 non-null   int64
#  4   Dt_Customer        8965 non-null   datetime64[ns]
#  5   NumWebVisitsMonth  8965 non-null   int64
#  6   ID                 8965 non-null   object
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 490.4+ KB

# %%
customers_2014 = pd.read_excel("../data/raw/customer-details.xlsx", sheet_name=2)
customers_2014.head()
# Out:
#    Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0           0  168812        1         1  2014-06-10                 27
# 1           1  108615        2         1  2014-04-05                 24
# 2           2  179041        0         2  2014-09-22                  4
# 3           3  116639        2         2  2014-08-16                  3
# 4           4   49537        0         1  2014-09-05                 28
#
#                                      ID
# 0  4d6c811c-0f24-4a73-b374-2ebd1f80d46e
# 1  eef0f24f-cbdb-4c67-b371-09d7bc59695e
# 2  bbfdcedd-199d-4927-94bb-5dad051ff471
# 3  e8ebb67d-4ee1-4615-b701-eefe3af607eb
# 4  f7f79ace-0024-4505-a401-f340946f0942

# %%
customers_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20115 entries, 0 to 20114
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         20115 non-null  int64
#  1   Income             20115 non-null  int64
#  2   Kidhome            20115 non-null  int64
#  3   Teenhome           20115 non-null  int64
#  4   Dt_Customer        20115 non-null  datetime64[ns]
#  5   NumWebVisitsMonth  20115 non-null  int64
#  6   ID                 20115 non-null  object
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 1.1+ MB

# %%
customers_2012.drop(columns="Unnamed: 0", inplace=True)
customers_2013.drop(columns="Unnamed: 0", inplace=True)
customers_2014.drop(columns="Unnamed: 0", inplace=True)

# %%
customers_2014.rename(columns={
    "ID": "id_"
}, inplace=True)
customers_2014.head()
# Out:
#    Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0  168812        1         1  2014-06-10                 27
# 1  108615        2         1  2014-04-05                 24
# 2  179041        0         2  2014-09-22                  4
# 3  116639        2         2  2014-08-16                  3
# 4   49537        0         1  2014-09-05                 28
#
#                                     id_
# 0  4d6c811c-0f24-4a73-b374-2ebd1f80d46e
# 1  eef0f24f-cbdb-4c67-b371-09d7bc59695e
# 2  bbfdcedd-199d-4927-94bb-5dad051ff471
# 3  e8ebb67d-4ee1-4615-b701-eefe3af607eb
# 4  f7f79ace-0024-4505-a401-f340946f0942

# %%
customers_2013.rename(columns={
    "ID": "id_"
}, inplace=True)
customers_2013.head()
# Out:
#    Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0   82407        0         1  2013-10-07                 29
# 1   24877        0         0  2013-04-21                 32
# 2   78839        1         0  2013-11-25                 21
# 3  113859        1         1  2013-01-06                 12
# 4  147317        0         0  2013-07-10                 14
#
#                                     id_
# 0  ef81336c-e41a-46d0-8a30-5d4ac3b836be
# 1  50b224ac-84b4-42a7-aba9-3e1d1d620479
# 2  9cb15c53-b647-464a-add9-09cdae04897c
# 3  f8aaf334-949d-4943-a214-b64fe9c088b4
# 4  885fe85a-3718-4760-a32a-a57628cf7528

# %%
customers_2012.rename(columns={
    "ID": "id_"
}, inplace=True)
customers_2012.head()
# Out:
#    Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0  161770        1         0  2012-04-04                 29
# 1   85477        1         1  2012-12-30                  7
# 2  147233        1         1  2012-02-02                  5
# 3  121393        1         2  2012-12-21                 29
# 4   63164        1         2  2012-06-20                 20
#
#                                     id_
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079
# 1  e9d37224-cb6f-4942-98d7-46672963d097
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b
# 3  9991fafb-4447-451a-8be2-b0df6098d13e
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb

# %%
customers_df = pd.concat([customers_2012, customers_2013, customers_2014], axis=0)
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43170 entries, 0 to 14089
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Income             43170 non-null  int64
#  1   Kidhome            43170 non-null  int64
#  2   Teenhome           43170 non-null  int64
#  3   Dt_Customer        43170 non-null  datetime64[ns]
#  4   NumWebVisitsMonth  43170 non-null  int64
#  5   id_                43170 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
print(len(customers_2012) + len(customers_2013) + len(customers_2014))
# Out:
# 43170

# %%
customers_df.isnull().sum()
# Out:
# Income               0
# Kidhome              0
# Teenhome             0
# Dt_Customer          0
# NumWebVisitsMonth    0
# id_                  0
# dtype: int64

# %%
customers_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(len(customers_df))
# Out:
# 43170

# %%
customers_df.id_.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers_df["Income"].describe()
# Out:
# count     43170.000000
# mean      93227.389622
# std       50498.181989
# min        5841.000000
# 25%       49608.000000
# 50%       93009.500000
# 75%      136740.500000
# max      180802.000000
# Name: Income, dtype: float64

# %%
customers_df["Total_children"] = customers_df["Kidhome"] + customers_df["Teenhome"]
customers_df.head()
# Out:
#    Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0  161770        1         0  2012-04-04                 29
# 1   85477        1         1  2012-12-30                  7
# 2  147233        1         1  2012-02-02                  5
# 3  121393        1         2  2012-12-21                 29
# 4   63164        1         2  2012-06-20                 20
#
#                                     id_  Total_children
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079               1
# 1  e9d37224-cb6f-4942-98d7-46672963d097               2
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b               2
# 3  9991fafb-4447-451a-8be2-b0df6098d13e               3
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb               3

# %%
customers_df.tail()
# Out:
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 14085  156980        1         2  2014-05-17                  7
# 14086  139820        0         0  2014-09-29                  1
# 14087   78470        2         2  2014-10-28                 12
# 14088  144218        0         1  2014-07-01                  9
# 14089  115155        0         2  2014-12-25                  7
#
#                                         id_  Total_children
# 14085  5f432048-d515-4bb5-9c94-62db451f88d4               3
# 14086  993bbbd6-4dbc-4a40-a408-f91f8462bee6               0
# 14087  d6271666-319d-42c8-a741-cb22bf2c2093               4
# 14088  f67fbfa8-6573-414d-a805-b26a2f1b1ceb               1
# 14089  9727bc06-c11a-461a-a5bb-3d210467cc2a               2

# %%
customers_df.to_csv("../data/processed/customer_clean.csv", index=False)
